# %%
import numpy as np

# %%
s=5  #escalar
s
# Out:
# 5

# %%
x=np.array([5,-2,4]) #vector
x
# Out:
# array([ 5, -2,  4])

# %%
m=np.array([[5,12,6],[-3,0,14]]) #esto es una matriz  de 2x3
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
type(s)
# Out:
# int

# %%
type(m)
# Out:
# numpy.ndarray

# %%
n_array=np.array(7) #esto es un escalar otra forma de escribirlo 
n_array
# Out:
# array(7)

# %%
m.shape
#nos muestra el tamaño de nuestra matriz
# Out:
# (2, 3)

# %%
x.reshape(1,3)#nos da un vector fila
# Out:
# array([[ 5, -2,  4]])

# %%
x.reshape(3,1)#nos da un vector columna
# Out:
# array([[ 5],
#        [-2],
#        [ 4]])

# %%
m1=np.array([[5,12,0],[-3,0,14]])
m1
# Out:
# array([[ 5, 12,  0],
#        [-3,  0, 14]])

# %%
m2=np.array([[9,8,7],[1,3,5]])
m2
# Out:
# array([[9, 8, 7],
#        [1, 3, 5]])

# %%
t=np.array([m1,m2])
t
# Out:
# array([[[ 5, 12,  0],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  3,  5]]])

# %%
t.shape #tiene 2matrices de 2x3
# Out:
# (2, 2, 3)

# %%
#tensor manual 
t_manual=np.array([[[5,1,4],[7,8,5]],[[7,2,8],[1,5,2]]])
t_manual
# Out:
# array([[[5, 1, 4],
#         [7, 8, 5]],
#
#        [[7, 2, 8],
#         [1, 5, 2]]])

# %%
#suma de matrices
m1+m2
# Out:
# array([[14, 20,  7],
#        [-2,  3, 19]])

# %%
m1-m2
# Out:
# array([[-4,  4, -7],
#        [-4, -3,  9]])

# %%
v1=np.array([1,4,7,8,9])
v2=np.array([2,3,1,5,6])

# %%
v1+v2  #suma de vectores
# Out:
# array([ 3,  7,  8, 13, 15])

# %%
y=np.array([1,2,5])
y
# Out:
# array([1, 2, 5])

# %%
y +1 #suma un escalar a un vector
# Out:
# array([2, 3, 6])

# %%
z= np.array([[2,3,4,4],[4,6,6,7]])
z
# Out:
# array([[2, 3, 4, 4],
#        [4, 6, 6, 7]])

# %%
z +1 #suma de 1 escalar a una matriz de 2x4
# Out:
# array([[3, 4, 5, 5],
#        [5, 7, 7, 8]])

# %%
#matriz transpuesta 
A=np.array([[5,12,6],[3,0,14]])
A
# Out:
# array([[ 5, 12,  6],
#        [ 3,  0, 14]])

# %%
A.T #esto me muetsra la matriz transpuesta
# Out:
# array([[ 5,  3],
#        [12,  0],
#        [ 6, 14]])

# %%
s=np.array([1,2,4])
s
# Out:
# array([1, 2, 4])

# %%
s.T #los vectores en python no se transponen
# Out:
# array([1, 2, 4])

# %%
#producto de matrices 
a=np.array([1,2,3])
b=np.array([2,3,4])

# %%
np.dot(a,b) #metodo de dot de numpy para producto
# Out:
# 20

# %%
np.dot(7,7) #producto de 2 escalares
# Out:
# 49

# %%
c=np.array([1,2,3])
c
# Out:
# array([1, 2, 3])

# %%
5*c #producto de 1 vector
# Out:
# array([ 5, 10, 15])

# %%
q=np.array([[1,3,2],[4,5,6]])
q
# Out:
# array([[1, 3, 2],
#        [4, 5, 6]])

# %%
3*q #producto de una matriz
# Out:
# array([[ 3,  9,  6],
#        [12, 15, 18]])

# %%
#producto de 2 matrices tienen en todos los casos la misma dimension .-
s=np.array([[1,2,3],[4,5,6]])
s
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
s1=np.array([[1,2],[3,4],[5,6]])
s1
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.dot(s,s1)
# Out:
# array([[22, 28],
#        [49, 64]])

# %%
e=np.array([[-12,5,-5,1,6],[6,-2,0,0,-3],[10,2,0,8,0],[9,-4,8,3,6]])
e
# Out:
# array([[-12,   5,  -5,   1,   6],
#        [  6,  -2,   0,   0,  -3],
#        [ 10,   2,   0,   8,   0],
#        [  9,  -4,   8,   3,   6]])

# %%
e1=np.array([[6,-1],[8,-4],[2,-2],[7,4],[-6,-9]])
e1
# Out:
# array([[ 6, -1],
#        [ 8, -4],
#        [ 2, -2],
#        [ 7,  4],
#        [-6, -9]])

# %%
np.dot(e,e1)
# Out:
# array([[-71, -48],
#        [ 38,  29],
#        [132,  14],
#        [ 23, -51]])
